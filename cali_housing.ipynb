# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# Load California Housing dataset
housing = fetch_california_housing()

X = housing.data
y = housing.target

# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training:", X_train.shape)
print("Testing:", X_test.shape)
# Out:
# Training: (16512, 8)
# Testing: (4128, 8)

# %%
from sklearn.neural_network import MLPRegressor
 
model = MLPRegressor(

    hidden_layer_sizes=(100, 50),

    activation="relu",

    solver="adam",

    max_iter=1000,

    early_stopping=True,

    random_state=42

)
 
model.fit(X_train, y_train)
# Out:
# MLPRegressor(early_stopping=True, hidden_layer_sizes=(100, 50), max_iter=1000,
#              random_state=42)

# %%
import matplotlib.pyplot as plt

train_predictions = model.predict(X_train)

plt.scatter(y_train, train_predictions, alpha=0.5)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Training Data: Actual vs Predicted")
plt.savefig("figures/train_actual_vs_predicted.png", dpi=300)
plt.show()

# %%
test_predictions = model.predict(X_test)
 
plt.scatter(y_test, test_predictions, alpha=0.5)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Test Data: Actual vs Predicted")
plt.savefig("figures/test_actual_vs_predicted.png", dpi=300)
plt.show()
